# %%
import csv

# %%
with open('games.csv') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    line_count = 0
    for row in csv_reader:
        if line_count == 0:
            print(f'Column names are {", ".join(row)}')
            line_count += 1
        else:
            print(f'\t{row}')
            line_count += 1
# Out:
# Column names are id, rated, created_at, last_move_at, turns, victory_status, winner, increment_code, white_id, white_rating, black_id, black_rating, moves, opening_eco, opening_name, opening_ply
# 	['TZJHLljE', 'FALSE', '1.50421E+12', '1.50421E+12', '13', 'outoftime', 'white', '15+2', 'bourgris', '1500', 'a-00', '1191', 'd4 d5 c4 c6 cxd5 e6 dxe6 fxe6 Nf3 Bb4+ Nc3 Ba5 Bf4', 'D10', 'Slav Defense: Exchange Variation', '5']
# 	['l1NXvwaE', 'TRUE', '1.50413E+12', '1.50413E+12', '16', 'resign', 'black', '5+10', 'a-00', '1322', 'skinnerua', '1261', 'd4 Nc6 e4 e5 f4 f6 dxe5 fxe5 fxe5 Nxe5 Qd4 Nc6 Qe5+ Nxe5 c4 Bb4+', 'B00', 'Nimzowitsch Defense: Kennedy Variation', '4']
# ...

# %%
f = open('games.csv')

# %%
reader = csv.reader(f, delimiter=',')

# %%
column_names = next(reader)

# %%
column_names
# Out:
# ['id',
#  'rated',
#  'created_at',
#  'last_move_at',
#  'turns',
#  'victory_status',
#  'winner',
#  'increment_code',
#  'white_id',
#  'white_rating',
#  'black_id',
#  'black_rating',
#  'moves',
#  'opening_eco',
#  'opening_name',
#  'opening_ply']

# %%
from datetime import datetime

# %%
def transform_row(row):
    created_at = str(val[2])
    last_move_at = str(val[3])
    row[2] = created_at
    row[3] = last_move_at

# %%
openings = set()
new_values = []

# %%
for row in reader:
    openings.add(tuple(row[-3:]))
    transform_row(row)
    new_values.append(row[:-3])

# %%
new_values
# Out:
# [['TZJHLljE',
#   'FALSE',
#   '2017-08-29 18:06:40',
#   '2017-08-29 18:06:40',
#   '13',
#   'outoftime',
#   'white',
#   '15+2',
#   'bourgris',
#   '1500',
#   'a-00',
#   '1191',
#   'd4 d5 c4 c6 cxd5 e6 dxe6 fxe6 Nf3 Bb4+ Nc3 Ba5 Bf4'],
#  ['l1NXvwaE',
#   'TRUE',
#   '2017-08-29 18:06:40',
#   '2017-08-29 18:06:40',
#   '16',
#   'resign',
#   'black',
#   '5+10',
#   'a-00',
#   '1322',
#   'skinnerua',
#   '1261',
#   'd4 Nc6 e4 e5 f4 f6 dxe5 fxe5 fxe5 Nxe5 Qd4 Nc6 Qe5+ Nxe5 c4 Bb4+'],
#  ['mIICvQHh',
#   'TRUE',
#   '2017-08-29 18:06:40',
#   '2017-08-29 18:06:40',
#   '61',
#   'mate',
#   'white',
#   '5+10',
#   'ischia',
#   '1496',
#   'a-00',
#   '1500',
#   'e4 e5 d3 d6 Be3 c6 Be2 b5 Nd2 a5 a4 c5 axb5 Nc6 bxc6 Ra6 Nc4 a4 c3 a3 Nxa3 Rxa3 Rxa3 c4 dxc4 d5 cxd5 Qxd5 exd5 Be6 Ra8+ Ke7 Bc5+ Kf6 Bxf8 Kg6 Bxg7 Kxg7 dxe6 Kh6 exf7 Nf6 Rxh8 Nh5 Bxh5 Kg5 Rxh7 Kf5 Qf3+ Ke6 Bg4+ Kd6 Rh6+ Kc5 Qe3+ Kb5 c4+ Kb4 Qc3+ Ka4 Bd1#'],
#  ['kWKvrqYL',
#   'TRUE',
#   '2017-08-29 18:06:40',
# ...

# %%
games_cols = column_names[:-3]
openings_cols = column_names[-3:]

# %%
openings_cols
# Out:
# ['opening_eco', 'opening_name', 'opening_ply']

# %%
with open('games_modified.csv', mode='w') as new_file:
    writer = csv.writer(new_file, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
    writer.writerow(games_cols)
    for row in new_values:
        writer.writerow(row)

# %%
with open('openings.csv', mode='w') as new_file:
    writer = csv.writer(new_file, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
    writer.writerow(openings_cols)
    for row in openings:
        writer.writerow(row)
